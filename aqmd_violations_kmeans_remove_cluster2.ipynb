# %% [markdown]
# ### Notes
# * https://medium.com/@luckylwk/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b
# * http://scikit-learn.org/stable/modules/manifold.html#t-sne
# * http://jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf
# * https://www.kaggle.com/thykhuely/mercari-interactive-eda-topic-modelling
# * https://www.dataquest.io/blog/build-a-data-science-portfolio/
# * https://www.youtube.com/watch?v=NEaUSP4YerM
# * http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
# * https://www.stat.berkeley.edu/~spector/s133/Clus.html
# * https://stats.stackexchange.com/questions/10540/how-to-interpret-mean-of-silhouette-plot
# * Visualize clusters with and without tSNE
# * Need to understand how to explain the variance of costs within the clusters
# * Need to plot silhouette charts

# %%
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE
import seaborn as sns
from nltk import word_tokenize
from collections import Counter
from wordcloud import WordCloud
from string import punctuation
from sklearn.decomposition import PCA
import re
# %matplotlib inline

# %%
file = 'http://bit.ly/aqmd-violations-final'
titlev = 'http://bit.ly/aqmd-titlev'
reclaim = 'http://bit.ly/aqmd-reclaim'

# %%
df_all = pd.read_csv(file)
df_titleV = pd.read_csv(titlev)
df_reclaim = pd.read_csv(reclaim)

# %%
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment
# 0  Failed to reconcile quarterly NOx emissions in...  NOX RECLAIM facility
# 1                Inaccurate QCERs.  Inaccurate APEP.  NOx RECLAIM facility
# 2  FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...                   NaN
# 3  FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...                   NaN
# 4  Selling architectural coatings within the SCAQ...                   NaN

# %%
df_all['facility_type'] = ''

# %%
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  Failed to reconcile quarterly NOx emissions in...  NOX RECLAIM facility
# 1                Inaccurate QCERs.  Inaccurate APEP.  NOx RECLAIM facility
# 2  FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...                   NaN
# 3  FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...                   NaN
# 4  Selling architectural coatings within the SCAQ...                   NaN
#
#   facility_type
# 0
# 1
# 2
# 3
# 4

# %%
df_titleV.head()
# Out:
#    Facility ID                        Facility Name         City County  \
# 0        35188                           3M COMPANY     MONROVIA     LA
# 1       800088                           3M COMPANY       CORONA     RV
# 2        45489  ABBOTT CARDIOVASCULAR SYSTEMS, INC.     TEMECULA     RV
# 3        47084                 ADVANCE PAPER BOX CO  LOS ANGELES     LA
# 4        57390           ADVANCE TRUCK PAINTING INC  PICO RIVERA     LA
#
#   Initial Issue Date Renewal Date
# 0            6/17/13          NaN
# 1             5/9/00       5/4/12
# 2           10/26/01      1/11/12
# 3            8/13/01      9/16/11
# 4            4/16/01       6/7/11

# %%
df_reclaim.head()
# Out:
#    Fac_id
# 0     136
# 1     346
# 2     550
# 3    1073
# 4    1744

# %%
reclaim_list = df_reclaim['Fac_id'].tolist()

# %%
titlev_list = df_titleV['Facility ID'].tolist()

# %%
reclaim_titlev_list = [facility for facility in titlev_list if facility in reclaim_list]

# %%
list_error = []
for index, row in df_all.iterrows():
    try:
        pd.to_numeric(row['facility id'])
    except:
        list_error.append(row)
list_error
# Out:
# [facility id                                                  16, 20
#  notification                                                 P57290
#  Attorney                                                        WBW
#  Total                                                         40000
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data    failure to conduct NOx emissions checks monthl...
#  equipment                                                       NaN
#  facility_type
#  Name: 475, dtype: object,
#  facility id                                                  16, 20
#  notification                                                 P57290
#  Attorney                                                        FAC
#  Total                                                         40000
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data    failure to conduct NOx emissions checks monthl...
#  equipment                                                       NaN
#  facility_type
#  Name: 476, dtype: object,
#  facility id                                                  16, 20
#  notification                                                 P57290
#  Attorney                                                        INT
#  Total                                                         40000
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data    failure to conduct NOx emissions checks monthl...
#  equipment                                                       NaN
#  facility_type
#  Name: 477, dtype: object,
#  facility id                                                  2344 2
#  notification                                                 P63673
#  Attorney                                                        KCM
#  Total                                                          1500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data    Fire pump exceeded 20 hours/year for maintenan...
#  equipment                                               1 Fire Pump
#  facility_type
#  Name: 1284, dtype: object,
#  facility id                                                  202, 2
#  notification                                                HRB2169
#  Attorney                                                        INT
#  Total                                                          1000
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 1695, dtype: object,
#  facility id                                                  31, 20
#  notification                                                  SRV97
#  Attorney                                                        WBW
#  Total                                                        213376
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 2066, dtype: object,
#  facility id                                                  31, 20
#  notification                                                  SRV97
#  Attorney                                                        INT
#  Total                                                        213376
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 2067, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2187
#  Attorney                                                        INT
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3138, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2191
#  Attorney                                                        INT
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3140, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2191
#  Attorney                                                        FAC
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3141, dtype: object]

# %%
for each in list_error:
    print(each['facility id'])
# Out:
# 16, 20
# 16, 20
# 16, 20
# 2344 2
# 202, 2
# 31, 20
# 31, 20
# 10/1
# 10/1
# 10/1

# %%
for each in list_error:
    print(each['notification'])
# Out:
# P57290
# P57290
# P57290
# P63673
# HRB2169
# SRV97
# SRV97
# HRB2187
# HRB2191
# HRB2191

# %%
df_all.iloc[475]['facility id']
df_all.set_value(475, 'facility id', '50134')
# Out:
#      facility id notification Attorney     Total  \
# 0           3704       P56324      KCM   7200.00
# 1           3704       P56323      KCM   7200.00
# 2           2526       P37231      BTG   3500.00
# 3           2526       P37230      BTG   3500.00
# 4         158141       P60306      WBW   9438.66
# 5         115862       P59039      NSF   1000.00
# 6         115862       P61478      NSF   1000.00
# 7         115862       P61475      NSF   1000.00
# 8         800057       P52622      BTG   3000.00
# 9          84456       P61702      NSF   2500.00
# 10        137966       P58832      KCM   1200.00
# 11        165580       P62241      WBW   1000.00
# 12        165580       P61253      WBW   1000.00
# 13         45471       P52196      KCM   1200.00
# 14        158910       P34696      NSF  10000.00
# 15        114801       P57815      BTG  10625.00
# 16        173194       P56835      NSF   1600.00
# 17        173194       P59918      NSF   1600.00
# 18        157644       P60324      LBN    500.00
# 19         11034       P55543      TRB   1000.00
# 20        800026       SRV105      KCM  71200.00
# 21        176308       P58087      KCM   1650.00
# 22        174718       P61707      KCM   1600.00
# 23        177675       P57693      KCM   5500.00
# 24        177813       P61439      KCM    770.00
# 25          6638       P61855      KCM   1500.00
# 26        171583       P59268      KCM    440.00
# 27        177814       P61437      KCM    275.00
# 28        158931       P60919      KCM    550.00
# 29        100542       P59374      KCM   1800.00
# ...          ...          ...      ...       ...
# 3658      168535    PERP 2460      MJR   1600.00
# 3659      178146       P61967      MJR    500.00
# 3660      178146       P61976      MJR   1000.00
# 3661      156040       P60080      MJR    600.00
# 3662      147358       P61961      MJR   3400.00
# 3663      180048       P57480      MJR   1000.00
# 3664      171673       P60938      MJR    550.00
# 3665      179225       P61260      MJR    690.00
# 3666      172373       P61964      MJR    800.00
# 3667      168709       P62342      MJR    550.00
# 3668      168709       P60835      MJR    650.00
# 3669      139576       P59523      MJR    800.00
# 3670      157547       P61970      MJR    650.00
# 3671      179992       P61717      MJR   2400.00
# 3672      134889       P64000      MJR   1600.00
# 3673      103978       P62436      MJR    650.00
# 3674      162826       P61193      MJR   1600.00
# 3675      172408       P63000      MJR    400.00
# 3676      167466       P61682      MJR    800.00
# 3677      133145       P60843      MJR    800.00
# 3678       35188      HRB2292      KCM   1064.00
# 3679        6331      HRB2293      TRB    600.00
# 3680      123715      HRB2294      MJR   1500.00
# 3681      123715      HRB2294      INT   1500.00
# 3682      104017       P56978      INT    500.00
# 3683      131310       P61556      BTG  21500.00
# 3684      164902       P58427      NSF   6000.00
# 3685      177014       P61550      KCM   4800.00
# 3686      177014       P58281      KCM   4800.00
# 3687      177014       P60415      KCM   4800.00
#
#                                                     url  \
# 0     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 5     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 6     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 7     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 8     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 9     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 10    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 11    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 12    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 13    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 14    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 15    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 16    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 17    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 18    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 21    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 22    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 23    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 24    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 25    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 26    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 27    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 28    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 29    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# ...                                                 ...
# 3658  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3659  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3660  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3661  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3662  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3663  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3664  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3665  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3666  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3667  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3668  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3669  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3670  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3671  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3672  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3673  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3674  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3675  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3676  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3677  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3678  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3679  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3680  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3681  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3682  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3683  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3684  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3685  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3686  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3687  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                          violation_data  \
# 0     Failed to reconcile quarterly NOx emissions in...
# 1                   Inaccurate QCERs.  Inaccurate APEP.
# 2     FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...
# 3     FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...
# 4     Selling architectural coatings within the SCAQ...
# 5     FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 6     Failure to post permit on site. Failure to pro...
# 7     Operating a gasoline dispensing facility contr...
# 8     TWO VAPOR RECOVERY HOSES LEAKING ABOVE 3,000 P...
# 9     Operating an AJAX boiler rated at 4.25 million...
# 10    Emitting more than permitted limit for NOx and...
# 11    Operating gasoline dispensing equipment after ...
# 12    Permit Condition - Gasoline Dispensing Facilit...
# 13    Failure to submit an Annual Permit Emissions P...
# 14                    Open ended line.  Uncapped valve.
# 15    Failed to submit daily emissions reports in a ...
# 16    Operating a gasoline dispensing facility not a...
# 17    FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE ...
# 18    Selling Architectural coatings within the SCAQ...
# 19    The electronic report of daily mass emissions ...
# 20                                                  NaN
# 21    Operating a diesel fueled engine during school...
# 22    Visible emissions in excess of 20% opacityfor ...
# 23    Exceede provided character space.  Please view...
# 24    The company was operating equipment without a ...
# 25    Failure to demonstrate compliance with the 30 ...
# 26    Operating a portable internal combustion engin...
# 27    The company was operating a 4 cylinder, Hatz, ...
# 28    Failure to show compliance by not performing p...
# 29    1146.1: Failing to demonstrate compliance to t...
# ...                                                 ...
# 3658                                                NaN
# 3659  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3660  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3661      INCORRECTLY INSTALLED BREAKAWAY ON NOZZLE #9.
# 3662  OPERATING CONTRARY TO PERMIT CONDITIONS - EXCE...
# 3663  OPERATION OF A CONSTRUCTION WITH TRACK OUT > 2...
# 3664  FAILURE TO SHOW COMPLIANCE BY OPERATING NOZZLE...
# 3665  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3666  OPERTAING A GASOLINE DISPENSING FACILITY WITH ...
# 3667  Failure to conduct vapor recovery testing in a...
# 3668  FAILURE TO CONDUCT REVERIFICATION TEST IN ACCO...
# 3669  Operating hydrocarbon dry cleaning machine wit...
# 3670  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3671  Allowing track out to extend 25 feet or more i...
# 3672  Rule 1470(c)(3)(C)(i)(I) - Diesel ICE powered ...
# 3673  ALTERATION PRIOR TO RECEIVING PERMIT TO CONSTR...
# 3674  Hurst boiler, rated at 1,974,000 BTU/hr: faili...
# 3675  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3676  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3677  FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682  Failure to submit the 2nd Quarter QCER in a ti...
# 3683  Operation of their permitted ICE (F91507) abov...
# 3684  Operation of a diesel emergency ice greater th...
# 3685  Operation of a facility that created a public ...
# 3686  H&S41700;/R402 - Operation of a facility in a ...
# 3687  Releasing air contaminants causing nuisance to...
#
#                                               equipment facility_type
# 0                                  NOX RECLAIM facility
# 1                                  NOx RECLAIM facility
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     to repair/replace vapor recovery components wi...
# 7                                                   NaN
# 8                                                   NaN
# 9              AJAX boiler rated at 4.25 million btu/hr
# 10                                                  NaN
# 11    operating with a Husky Model 4885 P/V Vent valve.
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                              RECLAIM Major Source D1
# 16                                  clearing ISD alarms
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                          charbroiler
# 23                      Boilers, Refrigerations Systems
# 24                 LPG storage tank, propane fueled ICE
# 25                                               Boiler
# 26                                                  NaN
# 27                                 concrete pump engine
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...           ...
# 3658                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3661                                                NaN
# 3662                                                NaN
# 3663  CONSTRUCTION SITE AT 5241 VANTAGE AVENUE, VALL...
# 3664                                                NaN
# 3665                                                NaN
# 3666                                                NaN
# 3667                                                NaN
# 3668                                                NaN
# 3669                               Dry Cleaning Machine
# 3670                                                NaN
# 3671                                                NaN
# 3672  BCAT - P/O F58844 - Cummins Diesel ICE powered...
# 3673                                                NaN
# 3674                           Natural gas fired boiler
# 3675                                                NaN
# 3676                                                NaN
# 3677                                                NaN
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682                                                NaN
# 3683                                                NaN
# 3684                                                NaN
# 3685  Recycling process generating odors from grease...
# 3686  A facility that processes materials collected ...
# 3687                                                NaN
#
# [3688 rows x 8 columns]

# %%
df_all.iloc[476]
df_all.set_value(476, 'facility id', '50134')
# Out:
#      facility id notification Attorney     Total  \
# 0           3704       P56324      KCM   7200.00
# 1           3704       P56323      KCM   7200.00
# 2           2526       P37231      BTG   3500.00
# 3           2526       P37230      BTG   3500.00
# 4         158141       P60306      WBW   9438.66
# 5         115862       P59039      NSF   1000.00
# 6         115862       P61478      NSF   1000.00
# 7         115862       P61475      NSF   1000.00
# 8         800057       P52622      BTG   3000.00
# 9          84456       P61702      NSF   2500.00
# 10        137966       P58832      KCM   1200.00
# 11        165580       P62241      WBW   1000.00
# 12        165580       P61253      WBW   1000.00
# 13         45471       P52196      KCM   1200.00
# 14        158910       P34696      NSF  10000.00
# 15        114801       P57815      BTG  10625.00
# 16        173194       P56835      NSF   1600.00
# 17        173194       P59918      NSF   1600.00
# 18        157644       P60324      LBN    500.00
# 19         11034       P55543      TRB   1000.00
# 20        800026       SRV105      KCM  71200.00
# 21        176308       P58087      KCM   1650.00
# 22        174718       P61707      KCM   1600.00
# 23        177675       P57693      KCM   5500.00
# 24        177813       P61439      KCM    770.00
# 25          6638       P61855      KCM   1500.00
# 26        171583       P59268      KCM    440.00
# 27        177814       P61437      KCM    275.00
# 28        158931       P60919      KCM    550.00
# 29        100542       P59374      KCM   1800.00
# ...          ...          ...      ...       ...
# 3658      168535    PERP 2460      MJR   1600.00
# 3659      178146       P61967      MJR    500.00
# 3660      178146       P61976      MJR   1000.00
# 3661      156040       P60080      MJR    600.00
# 3662      147358       P61961      MJR   3400.00
# 3663      180048       P57480      MJR   1000.00
# 3664      171673       P60938      MJR    550.00
# 3665      179225       P61260      MJR    690.00
# 3666      172373       P61964      MJR    800.00
# 3667      168709       P62342      MJR    550.00
# 3668      168709       P60835      MJR    650.00
# 3669      139576       P59523      MJR    800.00
# 3670      157547       P61970      MJR    650.00
# 3671      179992       P61717      MJR   2400.00
# 3672      134889       P64000      MJR   1600.00
# 3673      103978       P62436      MJR    650.00
# 3674      162826       P61193      MJR   1600.00
# 3675      172408       P63000      MJR    400.00
# 3676      167466       P61682      MJR    800.00
# 3677      133145       P60843      MJR    800.00
# 3678       35188      HRB2292      KCM   1064.00
# 3679        6331      HRB2293      TRB    600.00
# 3680      123715      HRB2294      MJR   1500.00
# 3681      123715      HRB2294      INT   1500.00
# 3682      104017       P56978      INT    500.00
# 3683      131310       P61556      BTG  21500.00
# 3684      164902       P58427      NSF   6000.00
# 3685      177014       P61550      KCM   4800.00
# 3686      177014       P58281      KCM   4800.00
# 3687      177014       P60415      KCM   4800.00
#
#                                                     url  \
# 0     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 5     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 6     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 7     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 8     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 9     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 10    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 11    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 12    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 13    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 14    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 15    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 16    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 17    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 18    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 21    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 22    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 23    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 24    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 25    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 26    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 27    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 28    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 29    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# ...                                                 ...
# 3658  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3659  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3660  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3661  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3662  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3663  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3664  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3665  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3666  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3667  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3668  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3669  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3670  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3671  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3672  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3673  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3674  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3675  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3676  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3677  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3678  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3679  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3680  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3681  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3682  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3683  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3684  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3685  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3686  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3687  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                          violation_data  \
# 0     Failed to reconcile quarterly NOx emissions in...
# 1                   Inaccurate QCERs.  Inaccurate APEP.
# 2     FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...
# 3     FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...
# 4     Selling architectural coatings within the SCAQ...
# 5     FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 6     Failure to post permit on site. Failure to pro...
# 7     Operating a gasoline dispensing facility contr...
# 8     TWO VAPOR RECOVERY HOSES LEAKING ABOVE 3,000 P...
# 9     Operating an AJAX boiler rated at 4.25 million...
# 10    Emitting more than permitted limit for NOx and...
# 11    Operating gasoline dispensing equipment after ...
# 12    Permit Condition - Gasoline Dispensing Facilit...
# 13    Failure to submit an Annual Permit Emissions P...
# 14                    Open ended line.  Uncapped valve.
# 15    Failed to submit daily emissions reports in a ...
# 16    Operating a gasoline dispensing facility not a...
# 17    FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE ...
# 18    Selling Architectural coatings within the SCAQ...
# 19    The electronic report of daily mass emissions ...
# 20                                                  NaN
# 21    Operating a diesel fueled engine during school...
# 22    Visible emissions in excess of 20% opacityfor ...
# 23    Exceede provided character space.  Please view...
# 24    The company was operating equipment without a ...
# 25    Failure to demonstrate compliance with the 30 ...
# 26    Operating a portable internal combustion engin...
# 27    The company was operating a 4 cylinder, Hatz, ...
# 28    Failure to show compliance by not performing p...
# 29    1146.1: Failing to demonstrate compliance to t...
# ...                                                 ...
# 3658                                                NaN
# 3659  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3660  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3661      INCORRECTLY INSTALLED BREAKAWAY ON NOZZLE #9.
# 3662  OPERATING CONTRARY TO PERMIT CONDITIONS - EXCE...
# 3663  OPERATION OF A CONSTRUCTION WITH TRACK OUT > 2...
# 3664  FAILURE TO SHOW COMPLIANCE BY OPERATING NOZZLE...
# 3665  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3666  OPERTAING A GASOLINE DISPENSING FACILITY WITH ...
# 3667  Failure to conduct vapor recovery testing in a...
# 3668  FAILURE TO CONDUCT REVERIFICATION TEST IN ACCO...
# 3669  Operating hydrocarbon dry cleaning machine wit...
# 3670  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3671  Allowing track out to extend 25 feet or more i...
# 3672  Rule 1470(c)(3)(C)(i)(I) - Diesel ICE powered ...
# 3673  ALTERATION PRIOR TO RECEIVING PERMIT TO CONSTR...
# 3674  Hurst boiler, rated at 1,974,000 BTU/hr: faili...
# 3675  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3676  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3677  FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682  Failure to submit the 2nd Quarter QCER in a ti...
# 3683  Operation of their permitted ICE (F91507) abov...
# 3684  Operation of a diesel emergency ice greater th...
# 3685  Operation of a facility that created a public ...
# 3686  H&S41700;/R402 - Operation of a facility in a ...
# 3687  Releasing air contaminants causing nuisance to...
#
#                                               equipment facility_type
# 0                                  NOX RECLAIM facility
# 1                                  NOx RECLAIM facility
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     to repair/replace vapor recovery components wi...
# 7                                                   NaN
# 8                                                   NaN
# 9              AJAX boiler rated at 4.25 million btu/hr
# 10                                                  NaN
# 11    operating with a Husky Model 4885 P/V Vent valve.
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                              RECLAIM Major Source D1
# 16                                  clearing ISD alarms
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                          charbroiler
# 23                      Boilers, Refrigerations Systems
# 24                 LPG storage tank, propane fueled ICE
# 25                                               Boiler
# 26                                                  NaN
# 27                                 concrete pump engine
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...           ...
# 3658                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3661                                                NaN
# 3662                                                NaN
# 3663  CONSTRUCTION SITE AT 5241 VANTAGE AVENUE, VALL...
# 3664                                                NaN
# 3665                                                NaN
# 3666                                                NaN
# 3667                                                NaN
# 3668                                                NaN
# 3669                               Dry Cleaning Machine
# 3670                                                NaN
# 3671                                                NaN
# 3672  BCAT - P/O F58844 - Cummins Diesel ICE powered...
# 3673                                                NaN
# 3674                           Natural gas fired boiler
# 3675                                                NaN
# 3676                                                NaN
# 3677                                                NaN
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682                                                NaN
# 3683                                                NaN
# 3684                                                NaN
# 3685  Recycling process generating odors from grease...
# 3686  A facility that processes materials collected ...
# 3687                                                NaN
#
# [3688 rows x 8 columns]

# %%
df_all.iloc[477]
df_all.set_value(477, 'facility id', '50134')
# Out:
#      facility id notification Attorney     Total  \
# 0           3704       P56324      KCM   7200.00
# 1           3704       P56323      KCM   7200.00
# 2           2526       P37231      BTG   3500.00
# 3           2526       P37230      BTG   3500.00
# 4         158141       P60306      WBW   9438.66
# 5         115862       P59039      NSF   1000.00
# 6         115862       P61478      NSF   1000.00
# 7         115862       P61475      NSF   1000.00
# 8         800057       P52622      BTG   3000.00
# 9          84456       P61702      NSF   2500.00
# 10        137966       P58832      KCM   1200.00
# 11        165580       P62241      WBW   1000.00
# 12        165580       P61253      WBW   1000.00
# 13         45471       P52196      KCM   1200.00
# 14        158910       P34696      NSF  10000.00
# 15        114801       P57815      BTG  10625.00
# 16        173194       P56835      NSF   1600.00
# 17        173194       P59918      NSF   1600.00
# 18        157644       P60324      LBN    500.00
# 19         11034       P55543      TRB   1000.00
# 20        800026       SRV105      KCM  71200.00
# 21        176308       P58087      KCM   1650.00
# 22        174718       P61707      KCM   1600.00
# 23        177675       P57693      KCM   5500.00
# 24        177813       P61439      KCM    770.00
# 25          6638       P61855      KCM   1500.00
# 26        171583       P59268      KCM    440.00
# 27        177814       P61437      KCM    275.00
# 28        158931       P60919      KCM    550.00
# 29        100542       P59374      KCM   1800.00
# ...          ...          ...      ...       ...
# 3658      168535    PERP 2460      MJR   1600.00
# 3659      178146       P61967      MJR    500.00
# 3660      178146       P61976      MJR   1000.00
# 3661      156040       P60080      MJR    600.00
# 3662      147358       P61961      MJR   3400.00
# 3663      180048       P57480      MJR   1000.00
# 3664      171673       P60938      MJR    550.00
# 3665      179225       P61260      MJR    690.00
# 3666      172373       P61964      MJR    800.00
# 3667      168709       P62342      MJR    550.00
# 3668      168709       P60835      MJR    650.00
# 3669      139576       P59523      MJR    800.00
# 3670      157547       P61970      MJR    650.00
# 3671      179992       P61717      MJR   2400.00
# 3672      134889       P64000      MJR   1600.00
# 3673      103978       P62436      MJR    650.00
# 3674      162826       P61193      MJR   1600.00
# 3675      172408       P63000      MJR    400.00
# 3676      167466       P61682      MJR    800.00
# 3677      133145       P60843      MJR    800.00
# 3678       35188      HRB2292      KCM   1064.00
# 3679        6331      HRB2293      TRB    600.00
# 3680      123715      HRB2294      MJR   1500.00
# 3681      123715      HRB2294      INT   1500.00
# 3682      104017       P56978      INT    500.00
# 3683      131310       P61556      BTG  21500.00
# 3684      164902       P58427      NSF   6000.00
# 3685      177014       P61550      KCM   4800.00
# 3686      177014       P58281      KCM   4800.00
# 3687      177014       P60415      KCM   4800.00
#
#                                                     url  \
# 0     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 5     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 6     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 7     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 8     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 9     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 10    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 11    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 12    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 13    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 14    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 15    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 16    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 17    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 18    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 21    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 22    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 23    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 24    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 25    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 26    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 27    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 28    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 29    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# ...                                                 ...
# 3658  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3659  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3660  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3661  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3662  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3663  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3664  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3665  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3666  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3667  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3668  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3669  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3670  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3671  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3672  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3673  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3674  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3675  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3676  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3677  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3678  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3679  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3680  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3681  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3682  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3683  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3684  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3685  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3686  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3687  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                          violation_data  \
# 0     Failed to reconcile quarterly NOx emissions in...
# 1                   Inaccurate QCERs.  Inaccurate APEP.
# 2     FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...
# 3     FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...
# 4     Selling architectural coatings within the SCAQ...
# 5     FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 6     Failure to post permit on site. Failure to pro...
# 7     Operating a gasoline dispensing facility contr...
# 8     TWO VAPOR RECOVERY HOSES LEAKING ABOVE 3,000 P...
# 9     Operating an AJAX boiler rated at 4.25 million...
# 10    Emitting more than permitted limit for NOx and...
# 11    Operating gasoline dispensing equipment after ...
# 12    Permit Condition - Gasoline Dispensing Facilit...
# 13    Failure to submit an Annual Permit Emissions P...
# 14                    Open ended line.  Uncapped valve.
# 15    Failed to submit daily emissions reports in a ...
# 16    Operating a gasoline dispensing facility not a...
# 17    FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE ...
# 18    Selling Architectural coatings within the SCAQ...
# 19    The electronic report of daily mass emissions ...
# 20                                                  NaN
# 21    Operating a diesel fueled engine during school...
# 22    Visible emissions in excess of 20% opacityfor ...
# 23    Exceede provided character space.  Please view...
# 24    The company was operating equipment without a ...
# 25    Failure to demonstrate compliance with the 30 ...
# 26    Operating a portable internal combustion engin...
# 27    The company was operating a 4 cylinder, Hatz, ...
# 28    Failure to show compliance by not performing p...
# 29    1146.1: Failing to demonstrate compliance to t...
# ...                                                 ...
# 3658                                                NaN
# 3659  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3660  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3661      INCORRECTLY INSTALLED BREAKAWAY ON NOZZLE #9.
# 3662  OPERATING CONTRARY TO PERMIT CONDITIONS - EXCE...
# 3663  OPERATION OF A CONSTRUCTION WITH TRACK OUT > 2...
# 3664  FAILURE TO SHOW COMPLIANCE BY OPERATING NOZZLE...
# 3665  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3666  OPERTAING A GASOLINE DISPENSING FACILITY WITH ...
# 3667  Failure to conduct vapor recovery testing in a...
# 3668  FAILURE TO CONDUCT REVERIFICATION TEST IN ACCO...
# 3669  Operating hydrocarbon dry cleaning machine wit...
# 3670  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3671  Allowing track out to extend 25 feet or more i...
# 3672  Rule 1470(c)(3)(C)(i)(I) - Diesel ICE powered ...
# 3673  ALTERATION PRIOR TO RECEIVING PERMIT TO CONSTR...
# 3674  Hurst boiler, rated at 1,974,000 BTU/hr: faili...
# 3675  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3676  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3677  FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682  Failure to submit the 2nd Quarter QCER in a ti...
# 3683  Operation of their permitted ICE (F91507) abov...
# 3684  Operation of a diesel emergency ice greater th...
# 3685  Operation of a facility that created a public ...
# 3686  H&S41700;/R402 - Operation of a facility in a ...
# 3687  Releasing air contaminants causing nuisance to...
#
#                                               equipment facility_type
# 0                                  NOX RECLAIM facility
# 1                                  NOx RECLAIM facility
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     to repair/replace vapor recovery components wi...
# 7                                                   NaN
# 8                                                   NaN
# 9              AJAX boiler rated at 4.25 million btu/hr
# 10                                                  NaN
# 11    operating with a Husky Model 4885 P/V Vent valve.
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                              RECLAIM Major Source D1
# 16                                  clearing ISD alarms
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                          charbroiler
# 23                      Boilers, Refrigerations Systems
# 24                 LPG storage tank, propane fueled ICE
# 25                                               Boiler
# 26                                                  NaN
# 27                                 concrete pump engine
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...           ...
# 3658                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3661                                                NaN
# 3662                                                NaN
# 3663  CONSTRUCTION SITE AT 5241 VANTAGE AVENUE, VALL...
# 3664                                                NaN
# 3665                                                NaN
# 3666                                                NaN
# 3667                                                NaN
# 3668                                                NaN
# 3669                               Dry Cleaning Machine
# 3670                                                NaN
# 3671                                                NaN
# 3672  BCAT - P/O F58844 - Cummins Diesel ICE powered...
# 3673                                                NaN
# 3674                           Natural gas fired boiler
# 3675                                                NaN
# 3676                                                NaN
# 3677                                                NaN
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682                                                NaN
# 3683                                                NaN
# 3684                                                NaN
# 3685  Recycling process generating odors from grease...
# 3686  A facility that processes materials collected ...
# 3687                                                NaN
#
# [3688 rows x 8 columns]

# %%
df_all.iloc[1284]
df_all.set_value(1284, 'facility id', '2344')
# Out:
#      facility id notification Attorney     Total  \
# 0           3704       P56324      KCM   7200.00
# 1           3704       P56323      KCM   7200.00
# 2           2526       P37231      BTG   3500.00
# 3           2526       P37230      BTG   3500.00
# 4         158141       P60306      WBW   9438.66
# 5         115862       P59039      NSF   1000.00
# 6         115862       P61478      NSF   1000.00
# 7         115862       P61475      NSF   1000.00
# 8         800057       P52622      BTG   3000.00
# 9          84456       P61702      NSF   2500.00
# 10        137966       P58832      KCM   1200.00
# 11        165580       P62241      WBW   1000.00
# 12        165580       P61253      WBW   1000.00
# 13         45471       P52196      KCM   1200.00
# 14        158910       P34696      NSF  10000.00
# 15        114801       P57815      BTG  10625.00
# 16        173194       P56835      NSF   1600.00
# 17        173194       P59918      NSF   1600.00
# 18        157644       P60324      LBN    500.00
# 19         11034       P55543      TRB   1000.00
# 20        800026       SRV105      KCM  71200.00
# 21        176308       P58087      KCM   1650.00
# 22        174718       P61707      KCM   1600.00
# 23        177675       P57693      KCM   5500.00
# 24        177813       P61439      KCM    770.00
# 25          6638       P61855      KCM   1500.00
# 26        171583       P59268      KCM    440.00
# 27        177814       P61437      KCM    275.00
# 28        158931       P60919      KCM    550.00
# 29        100542       P59374      KCM   1800.00
# ...          ...          ...      ...       ...
# 3658      168535    PERP 2460      MJR   1600.00
# 3659      178146       P61967      MJR    500.00
# 3660      178146       P61976      MJR   1000.00
# 3661      156040       P60080      MJR    600.00
# 3662      147358       P61961      MJR   3400.00
# 3663      180048       P57480      MJR   1000.00
# 3664      171673       P60938      MJR    550.00
# 3665      179225       P61260      MJR    690.00
# 3666      172373       P61964      MJR    800.00
# 3667      168709       P62342      MJR    550.00
# 3668      168709       P60835      MJR    650.00
# 3669      139576       P59523      MJR    800.00
# 3670      157547       P61970      MJR    650.00
# 3671      179992       P61717      MJR   2400.00
# 3672      134889       P64000      MJR   1600.00
# 3673      103978       P62436      MJR    650.00
# 3674      162826       P61193      MJR   1600.00
# 3675      172408       P63000      MJR    400.00
# 3676      167466       P61682      MJR    800.00
# 3677      133145       P60843      MJR    800.00
# 3678       35188      HRB2292      KCM   1064.00
# 3679        6331      HRB2293      TRB    600.00
# 3680      123715      HRB2294      MJR   1500.00
# 3681      123715      HRB2294      INT   1500.00
# 3682      104017       P56978      INT    500.00
# 3683      131310       P61556      BTG  21500.00
# 3684      164902       P58427      NSF   6000.00
# 3685      177014       P61550      KCM   4800.00
# 3686      177014       P58281      KCM   4800.00
# 3687      177014       P60415      KCM   4800.00
#
#                                                     url  \
# 0     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 5     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 6     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 7     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 8     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 9     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 10    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 11    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 12    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 13    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 14    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 15    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 16    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 17    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 18    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 21    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 22    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 23    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 24    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 25    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 26    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 27    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 28    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 29    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# ...                                                 ...
# 3658  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3659  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3660  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3661  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3662  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3663  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3664  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3665  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3666  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3667  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3668  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3669  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3670  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3671  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3672  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3673  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3674  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3675  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3676  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3677  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3678  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3679  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3680  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3681  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3682  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3683  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3684  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3685  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3686  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3687  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                          violation_data  \
# 0     Failed to reconcile quarterly NOx emissions in...
# 1                   Inaccurate QCERs.  Inaccurate APEP.
# 2     FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...
# 3     FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...
# 4     Selling architectural coatings within the SCAQ...
# 5     FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 6     Failure to post permit on site. Failure to pro...
# 7     Operating a gasoline dispensing facility contr...
# 8     TWO VAPOR RECOVERY HOSES LEAKING ABOVE 3,000 P...
# 9     Operating an AJAX boiler rated at 4.25 million...
# 10    Emitting more than permitted limit for NOx and...
# 11    Operating gasoline dispensing equipment after ...
# 12    Permit Condition - Gasoline Dispensing Facilit...
# 13    Failure to submit an Annual Permit Emissions P...
# 14                    Open ended line.  Uncapped valve.
# 15    Failed to submit daily emissions reports in a ...
# 16    Operating a gasoline dispensing facility not a...
# 17    FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE ...
# 18    Selling Architectural coatings within the SCAQ...
# 19    The electronic report of daily mass emissions ...
# 20                                                  NaN
# 21    Operating a diesel fueled engine during school...
# 22    Visible emissions in excess of 20% opacityfor ...
# 23    Exceede provided character space.  Please view...
# 24    The company was operating equipment without a ...
# 25    Failure to demonstrate compliance with the 30 ...
# 26    Operating a portable internal combustion engin...
# 27    The company was operating a 4 cylinder, Hatz, ...
# 28    Failure to show compliance by not performing p...
# 29    1146.1: Failing to demonstrate compliance to t...
# ...                                                 ...
# 3658                                                NaN
# 3659  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3660  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3661      INCORRECTLY INSTALLED BREAKAWAY ON NOZZLE #9.
# 3662  OPERATING CONTRARY TO PERMIT CONDITIONS - EXCE...
# 3663  OPERATION OF A CONSTRUCTION WITH TRACK OUT > 2...
# 3664  FAILURE TO SHOW COMPLIANCE BY OPERATING NOZZLE...
# 3665  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3666  OPERTAING A GASOLINE DISPENSING FACILITY WITH ...
# 3667  Failure to conduct vapor recovery testing in a...
# 3668  FAILURE TO CONDUCT REVERIFICATION TEST IN ACCO...
# 3669  Operating hydrocarbon dry cleaning machine wit...
# 3670  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3671  Allowing track out to extend 25 feet or more i...
# 3672  Rule 1470(c)(3)(C)(i)(I) - Diesel ICE powered ...
# 3673  ALTERATION PRIOR TO RECEIVING PERMIT TO CONSTR...
# 3674  Hurst boiler, rated at 1,974,000 BTU/hr: faili...
# 3675  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3676  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3677  FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682  Failure to submit the 2nd Quarter QCER in a ti...
# 3683  Operation of their permitted ICE (F91507) abov...
# 3684  Operation of a diesel emergency ice greater th...
# 3685  Operation of a facility that created a public ...
# 3686  H&S41700;/R402 - Operation of a facility in a ...
# 3687  Releasing air contaminants causing nuisance to...
#
#                                               equipment facility_type
# 0                                  NOX RECLAIM facility
# 1                                  NOx RECLAIM facility
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     to repair/replace vapor recovery components wi...
# 7                                                   NaN
# 8                                                   NaN
# 9              AJAX boiler rated at 4.25 million btu/hr
# 10                                                  NaN
# 11    operating with a Husky Model 4885 P/V Vent valve.
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                              RECLAIM Major Source D1
# 16                                  clearing ISD alarms
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                          charbroiler
# 23                      Boilers, Refrigerations Systems
# 24                 LPG storage tank, propane fueled ICE
# 25                                               Boiler
# 26                                                  NaN
# 27                                 concrete pump engine
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...           ...
# 3658                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3661                                                NaN
# 3662                                                NaN
# 3663  CONSTRUCTION SITE AT 5241 VANTAGE AVENUE, VALL...
# 3664                                                NaN
# 3665                                                NaN
# 3666                                                NaN
# 3667                                                NaN
# 3668                                                NaN
# 3669                               Dry Cleaning Machine
# 3670                                                NaN
# 3671                                                NaN
# 3672  BCAT - P/O F58844 - Cummins Diesel ICE powered...
# 3673                                                NaN
# 3674                           Natural gas fired boiler
# 3675                                                NaN
# 3676                                                NaN
# 3677                                                NaN
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682                                                NaN
# 3683                                                NaN
# 3684                                                NaN
# 3685  Recycling process generating odors from grease...
# 3686  A facility that processes materials collected ...
# 3687                                                NaN
#
# [3688 rows x 8 columns]

# %%
list_error = []
for index, row in df_all.iterrows():
    try:
        pd.to_numeric(row['facility id'])
    except:
        list_error.append(row)
list_error
# Out:
# [facility id                                                  202, 2
#  notification                                                HRB2169
#  Attorney                                                        INT
#  Total                                                          1000
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 1695, dtype: object,
#  facility id                                                  31, 20
#  notification                                                  SRV97
#  Attorney                                                        WBW
#  Total                                                        213376
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 2066, dtype: object,
#  facility id                                                  31, 20
#  notification                                                  SRV97
#  Attorney                                                        INT
#  Total                                                        213376
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 2067, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2187
#  Attorney                                                        INT
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3138, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2191
#  Attorney                                                        INT
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3140, dtype: object,
#  facility id                                                    10/1
#  notification                                                HRB2191
#  Attorney                                                        FAC
#  Total                                                           500
#  url               http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#  violation_data                                                  NaN
#  equipment                                                       NaN
#  facility_type
#  Name: 3141, dtype: object]

# %%
for each in list_error:
    print(each['facility id'])
# Out:
# 202, 2
# 31, 20
# 31, 20
# 10/1
# 10/1
# 10/1

# %%
for each in list_error:
    print(each['notification'])
# Out:
# HRB2169
# SRV97
# SRV97
# HRB2187
# HRB2191
# HRB2191

# %%
df_all.drop(df_all.index[1695])
# Out:
#      facility id notification Attorney     Total  \
# 0           3704       P56324      KCM   7200.00
# 1           3704       P56323      KCM   7200.00
# 2           2526       P37231      BTG   3500.00
# 3           2526       P37230      BTG   3500.00
# 4         158141       P60306      WBW   9438.66
# 5         115862       P59039      NSF   1000.00
# 6         115862       P61478      NSF   1000.00
# 7         115862       P61475      NSF   1000.00
# 8         800057       P52622      BTG   3000.00
# 9          84456       P61702      NSF   2500.00
# 10        137966       P58832      KCM   1200.00
# 11        165580       P62241      WBW   1000.00
# 12        165580       P61253      WBW   1000.00
# 13         45471       P52196      KCM   1200.00
# 14        158910       P34696      NSF  10000.00
# 15        114801       P57815      BTG  10625.00
# 16        173194       P56835      NSF   1600.00
# 17        173194       P59918      NSF   1600.00
# 18        157644       P60324      LBN    500.00
# 19         11034       P55543      TRB   1000.00
# 20        800026       SRV105      KCM  71200.00
# 21        176308       P58087      KCM   1650.00
# 22        174718       P61707      KCM   1600.00
# 23        177675       P57693      KCM   5500.00
# 24        177813       P61439      KCM    770.00
# 25          6638       P61855      KCM   1500.00
# 26        171583       P59268      KCM    440.00
# 27        177814       P61437      KCM    275.00
# 28        158931       P60919      KCM    550.00
# 29        100542       P59374      KCM   1800.00
# ...          ...          ...      ...       ...
# 3658      168535    PERP 2460      MJR   1600.00
# 3659      178146       P61967      MJR    500.00
# 3660      178146       P61976      MJR   1000.00
# 3661      156040       P60080      MJR    600.00
# 3662      147358       P61961      MJR   3400.00
# 3663      180048       P57480      MJR   1000.00
# 3664      171673       P60938      MJR    550.00
# 3665      179225       P61260      MJR    690.00
# 3666      172373       P61964      MJR    800.00
# 3667      168709       P62342      MJR    550.00
# 3668      168709       P60835      MJR    650.00
# 3669      139576       P59523      MJR    800.00
# 3670      157547       P61970      MJR    650.00
# 3671      179992       P61717      MJR   2400.00
# 3672      134889       P64000      MJR   1600.00
# 3673      103978       P62436      MJR    650.00
# 3674      162826       P61193      MJR   1600.00
# 3675      172408       P63000      MJR    400.00
# 3676      167466       P61682      MJR    800.00
# 3677      133145       P60843      MJR    800.00
# 3678       35188      HRB2292      KCM   1064.00
# 3679        6331      HRB2293      TRB    600.00
# 3680      123715      HRB2294      MJR   1500.00
# 3681      123715      HRB2294      INT   1500.00
# 3682      104017       P56978      INT    500.00
# 3683      131310       P61556      BTG  21500.00
# 3684      164902       P58427      NSF   6000.00
# 3685      177014       P61550      KCM   4800.00
# 3686      177014       P58281      KCM   4800.00
# 3687      177014       P60415      KCM   4800.00
#
#                                                     url  \
# 0     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 5     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 6     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 7     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 8     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 9     http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 10    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 11    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 12    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 13    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 14    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 15    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 16    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 17    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 18    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 21    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 22    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 23    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 24    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 25    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 26    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 27    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 28    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 29    http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# ...                                                 ...
# 3658  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3659  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3660  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3661  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3662  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3663  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3664  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3665  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3666  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3667  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3668  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3669  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3670  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3671  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3672  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3673  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3674  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3675  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3676  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3677  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3678  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3679  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3680  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3681  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3682  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3683  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3684  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3685  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3686  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3687  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                          violation_data  \
# 0     Failed to reconcile quarterly NOx emissions in...
# 1                   Inaccurate QCERs.  Inaccurate APEP.
# 2     FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...
# 3     FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...
# 4     Selling architectural coatings within the SCAQ...
# 5     FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 6     Failure to post permit on site. Failure to pro...
# 7     Operating a gasoline dispensing facility contr...
# 8     TWO VAPOR RECOVERY HOSES LEAKING ABOVE 3,000 P...
# 9     Operating an AJAX boiler rated at 4.25 million...
# 10    Emitting more than permitted limit for NOx and...
# 11    Operating gasoline dispensing equipment after ...
# 12    Permit Condition - Gasoline Dispensing Facilit...
# 13    Failure to submit an Annual Permit Emissions P...
# 14                    Open ended line.  Uncapped valve.
# 15    Failed to submit daily emissions reports in a ...
# 16    Operating a gasoline dispensing facility not a...
# 17    FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE ...
# 18    Selling Architectural coatings within the SCAQ...
# 19    The electronic report of daily mass emissions ...
# 20                                                  NaN
# 21    Operating a diesel fueled engine during school...
# 22    Visible emissions in excess of 20% opacityfor ...
# 23    Exceede provided character space.  Please view...
# 24    The company was operating equipment without a ...
# 25    Failure to demonstrate compliance with the 30 ...
# 26    Operating a portable internal combustion engin...
# 27    The company was operating a 4 cylinder, Hatz, ...
# 28    Failure to show compliance by not performing p...
# 29    1146.1: Failing to demonstrate compliance to t...
# ...                                                 ...
# 3658                                                NaN
# 3659  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3660  OPERATING A GASOLINE DISPENSING FACILITY WITHO...
# 3661      INCORRECTLY INSTALLED BREAKAWAY ON NOZZLE #9.
# 3662  OPERATING CONTRARY TO PERMIT CONDITIONS - EXCE...
# 3663  OPERATION OF A CONSTRUCTION WITH TRACK OUT > 2...
# 3664  FAILURE TO SHOW COMPLIANCE BY OPERATING NOZZLE...
# 3665  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3666  OPERTAING A GASOLINE DISPENSING FACILITY WITH ...
# 3667  Failure to conduct vapor recovery testing in a...
# 3668  FAILURE TO CONDUCT REVERIFICATION TEST IN ACCO...
# 3669  Operating hydrocarbon dry cleaning machine wit...
# 3670  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3671  Allowing track out to extend 25 feet or more i...
# 3672  Rule 1470(c)(3)(C)(i)(I) - Diesel ICE powered ...
# 3673  ALTERATION PRIOR TO RECEIVING PERMIT TO CONSTR...
# 3674  Hurst boiler, rated at 1,974,000 BTU/hr: faili...
# 3675  OPERATING A GASOLINE DISPENSING FACILITY CONTR...
# 3676  OPERATING A GASOLINE DISPENSING FACILITY WITH ...
# 3677  FAILURE TO CONDUCT REVERIFICATION TEST 6 MONTH...
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682  Failure to submit the 2nd Quarter QCER in a ti...
# 3683  Operation of their permitted ICE (F91507) abov...
# 3684  Operation of a diesel emergency ice greater th...
# 3685  Operation of a facility that created a public ...
# 3686  H&S41700;/R402 - Operation of a facility in a ...
# 3687  Releasing air contaminants causing nuisance to...
#
#                                               equipment facility_type
# 0                                  NOX RECLAIM facility
# 1                                  NOx RECLAIM facility
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     to repair/replace vapor recovery components wi...
# 7                                                   NaN
# 8                                                   NaN
# 9              AJAX boiler rated at 4.25 million btu/hr
# 10                                                  NaN
# 11    operating with a Husky Model 4885 P/V Vent valve.
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                              RECLAIM Major Source D1
# 16                                  clearing ISD alarms
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                          charbroiler
# 23                      Boilers, Refrigerations Systems
# 24                 LPG storage tank, propane fueled ICE
# 25                                               Boiler
# 26                                                  NaN
# 27                                 concrete pump engine
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...           ...
# 3658                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3661                                                NaN
# 3662                                                NaN
# 3663  CONSTRUCTION SITE AT 5241 VANTAGE AVENUE, VALL...
# 3664                                                NaN
# 3665                                                NaN
# 3666                                                NaN
# 3667                                                NaN
# 3668                                                NaN
# 3669                               Dry Cleaning Machine
# 3670                                                NaN
# 3671                                                NaN
# 3672  BCAT - P/O F58844 - Cummins Diesel ICE powered...
# 3673                                                NaN
# 3674                           Natural gas fired boiler
# 3675                                                NaN
# 3676                                                NaN
# 3677                                                NaN
# 3678                                                NaN
# 3679                                                NaN
# 3680                                                NaN
# 3681                                                NaN
# 3682                                                NaN
# 3683                                                NaN
# 3684                                                NaN
# 3685  Recycling process generating odors from grease...
# 3686  A facility that processes materials collected ...
# 3687                                                NaN
#
# [3687 rows x 8 columns]

# %%
list_error = []
for index, row in df_all.iterrows():
    try:
        pd.to_numeric(row['facility id'])
    except:
        list_error.append(row)
        print(index)
# Out:
# 1695
# 2066
# 2067
# 3138
# 3140
# 3141

# %%
df_all = df_all.drop(df_all.index[[1695,
2066,
2067,
3138,
3140,
3141]])

# %%
list_error = []
for index, row in df_all.iterrows():
    try:
        pd.to_numeric(row['facility id'])
    except:
        list_error.append(row)
        print(index)

# %%
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  Failed to reconcile quarterly NOx emissions in...  NOX RECLAIM facility
# 1                Inaccurate QCERs.  Inaccurate APEP.  NOx RECLAIM facility
# 2  FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...                   NaN
# 3  FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...                   NaN
# 4  Selling architectural coatings within the SCAQ...                   NaN
#
#   facility_type
# 0
# 1
# 2
# 3
# 4

# %%
index_row = []
for index, row in df_all.iterrows():
    try:
        if float(row['facility id']) in titlev_list:
            df_all.set_value(index, 'facility_type', 't')
        elif float(row['facility id']) in reclaim_list:
            df_all.set_value(index, 'facility_type', 'r')
        else:
            df_all.set_value(index, 'facility_type', 'n')
    except:
        index_row.append(row)
index_row
# Out:
# []

# %%
index_row = []
for index, row in df_all.iterrows():
    try:
        if float(row['facility id']) in reclaim_titlev_list:
            df_all.set_value(index, 'facility_type', 'rt')
    except:
        index_row.append(row)
index_row
# Out:
# []

# %%
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  Failed to reconcile quarterly NOx emissions in...  NOX RECLAIM facility
# 1                Inaccurate QCERs.  Inaccurate APEP.  NOx RECLAIM facility
# 2  FAILURE TO KEEP THE ROOF OF INTERNAL FLOATING ...                   NaN
# 3  FAILURE TO OPERATE AND MAINTAIN A CONTINUOUS M...                   NaN
# 4  Selling architectural coatings within the SCAQ...                   NaN
#
#   facility_type
# 0            rt
# 1            rt
# 2             t
# 3             t
# 4             n

# %%
df_all.shape
# Out:
# (3682, 8)

# %%
df_rt = df_all[(df_all['facility_type'] == 'rt')]
df_rt.head()
# Out:
#    facility id notification Attorney    Total  \
# 0         3704       P56324      KCM   7200.0
# 1         3704       P56323      KCM   7200.0
# 19       11034       P55543      TRB   1000.0
# 20      800026       SRV105      KCM  71200.0
# 69      800408       P59376      TRB   1000.0
#
#                                                   url  \
# 0   http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1   http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 19  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 20  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 69  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                        violation_data             equipment  \
# 0   Failed to reconcile quarterly NOx emissions in...  NOX RECLAIM facility
# 1                 Inaccurate QCERs.  Inaccurate APEP.  NOx RECLAIM facility
# 19  The electronic report of daily mass emissions ...                   NaN
# 20                                                NaN                   NaN
# 69  Operating Device #C160 contrary to permit cond...                   NaN
#
#    facility_type
# 0             rt
# 1             rt
# 19            rt
# 20            rt
# 69            rt

# %%
df_facility_average = df_all.groupby(['facility_type'], as_index=False).mean()
df_facility_average
# Out:
#   facility_type          Total
# 0             n   11762.097454
# 1             r   38479.358108
# 2            rt  523801.033898
# 3             t  446882.295084

# %%
punctuation_symbols = []
for each in list(punctuation):
    punctuation_symbols.append((each))

# %%
set(df_all['facility_type'].tolist())
# Out:
# {'n', 'r', 'rt', 't'}

# %%
len(df_all['facility_type'].tolist())
# Out:
# 3682

# %%
df_all = df_all.dropna(subset=['violation_data'])
df_all.shape
# Out:
# (3336, 8)

# %%
def remove_puncuation(d):
    for each in punctuation_symbols:
        d = d.replace(each, '')
    return d

# %%
def remove_digits(x):
    x = ''.join([i for i in x if not i.isdigit()])
    return x

# %%
df_all['violation_data'] = df_all.violation_data.apply(remove_digits)
df_all['violation_data'] = df_all.violation_data.apply(remove_puncuation)
df_all['violation_data'] = df_all['violation_data'].str.lower()

# %%
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  failed to reconcile quarterly nox emissions in...  NOX RECLAIM facility
# 1                  inaccurate qcers  inaccurate apep  NOx RECLAIM facility
# 2  failure to keep the roof of internal floating ...                   NaN
# 3  failure to operate and maintain a continuous m...                   NaN
# 4  selling architectural coatings within the scaq...                   NaN
#
#   facility_type
# 0            rt
# 1            rt
# 2             t
# 3             t
# 4             n

# %%
df_all['trim_violation_text'] = ''
for index, row in df_all.iterrows():
    df_all.set_value(index, 'trim_violation_text', re.sub(r' +', ' ', str(row['violation_data'])))
df_all.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  failed to reconcile quarterly nox emissions in...  NOX RECLAIM facility
# 1                  inaccurate qcers  inaccurate apep  NOx RECLAIM facility
# 2  failure to keep the roof of internal floating ...                   NaN
# 3  failure to operate and maintain a continuous m...                   NaN
# 4  selling architectural coatings within the scaq...                   NaN
#
#   facility_type                                trim_violation_text
# 0            rt  failed to reconcile quarterly nox emissions in...
# 1            rt                   inaccurate qcers inaccurate apep
# 2             t  failure to keep the roof of internal floating ...
# 3             t  failure to operate and maintain a continuous m...
# 4             n  selling architectural coatings within the scaq...

# %%
df_all['violation_data'].isnull().sum()
# Out:
# 0

# %%
df_all.shape
# Out:
# (3336, 9)

# %%
sunshine = ['49111']

df_all2 = df_all.loc[~df_all['facility id'].isin(sunshine)].reset_index(drop=True)

# %%
df_all2.shape
# Out:
# (3204, 9)

# %%
facility_type_ = dict()
type_list = ['rt', 't', 'r', 'n']
for each in type_list:
    text = ' '.join(df_all2.loc[df_all2['facility_type'] == each, 'trim_violation_text'].values)
    facility_type_[each] = word_tokenize(text)

# %%
none_top100 = Counter(facility_type_['n']).most_common(100)
reclaim_top100 = Counter(facility_type_['r']).most_common(100)
titlev_top100 = Counter(facility_type_['t']).most_common(100)
reclaim_titlev_top100 = Counter(facility_type_['rt']).most_common(100)

# %%
def create_wordcloud(d):
    wordcloud = WordCloud(background_color='white',
                          max_words=75, 
                          max_font_size=40,
                          random_state=42).generate(str(d))
    return wordcloud

# %%
fig, axes = plt.subplots(2, 2, figsize=(30, 15))

ax = axes[0, 0]
ax.imshow(create_wordcloud(none_top100), interpolation="bilinear")
ax.axis('off')
ax.set_title("Non-RECLAIM/Title V Top 100 Tokens", fontsize=30)

ax = axes[0, 1]
ax.imshow(create_wordcloud(reclaim_top100))
ax.axis('off')
ax.set_title("RECLAIM Top 100 Tokens", fontsize=30)

ax = axes[1, 0]
ax.imshow(create_wordcloud(titlev_top100))
ax.axis('off')
ax.set_title("Title V Top 100 Tokens", fontsize=30)

ax = axes[1, 1]
ax.imshow(create_wordcloud(reclaim_titlev_top100))
ax.axis('off')
ax.set_title("RECLAIM/Title V Top 100 Tokens", fontsize=30)
plt.show()

# %%
plt.subplot(1, 3, 1)
(df_all2['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,1500000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$,1,500,000', fontsize=17)

plt.subplot(1, 3, 2)
(df_all2['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,25000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$25,000', fontsize=17)

plt.subplot(1, 3, 3)
(np.log(df_all2['Total'] + 1)).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,17])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: log(x + 1)', fontsize=17)
plt.show()

#https://www.quora.com/What-are-the-downsides-when-using-log-x-+-1-as-ones-log-transformation
#http://onbiostatistics.blogspot.com/2012/05/logx1-data-transformation.html

# %%
facility_count = df_all2[['Total','facility_type']].groupby(['facility_type'], as_index =False).count()
facility_count
# Out:
#   facility_type  Total
# 0             n   2552
# 1             r    142
# 2            rt    282
# 3             t    228

# %%
sns.barplot(facility_count['facility_type'], facility_count['Total'])
plt.grid(True)
plt.ylim(0, 3000, 100)
plt.xlabel('Facility Type', fontsize = 14)
plt.ylabel('Number of Violations', fontsize = 14)
plt.title('Number of Violations By Facility Type', fontsize = 14)
plt.show()

# %%
df_none = df_all2[df_all2['facility_type'] == 'n'].reset_index(drop=True)
df_rt = df_all2[df_all2['facility_type'] == 'rt'].reset_index(drop=True)
df_r = df_all2[df_all2['facility_type'] == 'r'].reset_index(drop=True)
df_t = df_all2[df_all2['facility_type'] == 't'].reset_index(drop=True)

# %%
plt.subplot(1, 3, 1)
(df_none['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,1500000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$,1,500,000', fontsize=17)

plt.subplot(1, 3, 2)
(df_none['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,25000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$25,000', fontsize=17)

plt.subplot(1, 3, 3)
(np.log(df_none['Total'] + 1)).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,17])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: log(x + 1)', fontsize=17)
plt.show()

# %%
plt.subplot(1, 3, 1)
(df_rt['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,1500000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$,1,500,000', fontsize=17)

plt.subplot(1, 3, 2)
(df_rt['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,25000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$25,000', fontsize=17)

plt.subplot(1, 3, 3)
(np.log(df_rt['Total'] + 1)).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,17])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: log(x + 1)', fontsize=17)
plt.show()

# %%
plt.subplot(1, 3, 1)
(df_r['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,1500000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$,1,500,000', fontsize=17)

plt.subplot(1, 3, 2)
(df_r['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,25000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$25,000', fontsize=17)

plt.subplot(1, 3, 3)
(np.log(df_r['Total'] + 1)).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,17])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: log(x + 1)', fontsize=17)
plt.show()

# %%
plt.subplot(1, 3, 1)
(df_t['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,1500000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$,1,500,000', fontsize=17)

plt.subplot(1, 3, 2)
(df_t['Total']).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,25000])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: $0-$25,000', fontsize=17)

plt.subplot(1, 3, 3)
(np.log(df_t['Total'] + 1)).plot.hist(bins=50, figsize=(20,10), edgecolor='white',range=[0,17])
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Frequency', fontsize=17)
plt.tick_params(labelsize=15)
plt.title('Settlement Distribution :: log(x + 1)', fontsize=17)
plt.show()

# %%
sns.set_style('whitegrid')
data = df_all2[df_all2['Total'] < 20000]
ax = sns.boxplot(x="Total", y="facility_type", data=data)
plt.xlabel('Settlement Cost', fontsize=17)
plt.ylabel('Facility Type', fontsize=17)
plt.show()

# %%
min_df = 0.01
max_df = 0.90
vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))

# %%
X = df_all2['violation_data']
y = df_all2['facility_type']

# %%
def determine_length(d):
    d = d.split(' ')
    return len(d)

# %%
df_all2['violation_length'] = df_all2['trim_violation_text'].apply(determine_length)

# %%
df_all2.iloc[1]['trim_violation_text'].split(' ')
# Out:
# ['inaccurate', 'qcers', 'inaccurate', 'apep']

# %%
df_all2.iloc[1]['violation_length']
# Out:
# 4

# %%
df_all2.head()
# Out:
#   facility id notification Attorney    Total  \
# 0        3704       P56324      KCM  7200.00
# 1        3704       P56323      KCM  7200.00
# 2        2526       P37231      BTG  3500.00
# 3        2526       P37230      BTG  3500.00
# 4      158141       P60306      WBW  9438.66
#
#                                                  url  \
# 0  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 1  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 2  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 3  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
# 4  http://www3.aqmd.gov/webappl/fim/prog/novdetai...
#
#                                       violation_data             equipment  \
# 0  failed to reconcile quarterly nox emissions in...  NOX RECLAIM facility
# 1                  inaccurate qcers  inaccurate apep  NOx RECLAIM facility
# 2  failure to keep the roof of internal floating ...                   NaN
# 3  failure to operate and maintain a continuous m...                   NaN
# 4  selling architectural coatings within the scaq...                   NaN
#
#   facility_type                                trim_violation_text  \
# 0            rt  failed to reconcile quarterly nox emissions in...
# 1            rt                   inaccurate qcers inaccurate apep
# 2             t  failure to keep the roof of internal floating ...
# 3             t  failure to operate and maintain a continuous m...
# 4             n  selling architectural coatings within the scaq...
#
#    violation_length
# 0                42
# 1                 4
# 2                22
# 3                14
# 4                25

# %%
df_len_cost = df_all2[['Total', 'violation_length']].groupby(['violation_length'], as_index=False).mean()
df_len_cost.head()
# Out:
#    violation_length          Total
# 0                 1    5187.500000
# 1                 2  765327.272727
# 2                 3   35393.750000
# 3                 4   31681.250000
# 4                 5  121657.500000

# %%
plt.figure(figsize = (10, 10))
sns.jointplot(x=df_len_cost["Total"], y=df_len_cost["violation_length"], kind='kde', color = 'b')
plt.show()

# %%
x = np.log(df_len_cost['violation_length'])
y = np.log(df_len_cost['Total'])
plt.scatter(x, y)
plt.plot(x, y)
plt.ylabel('log(Average Settlement Cost)')
plt.xlabel('log(Length of Violation (number of words))')
plt.title('Average Settlement Cost vs Length of Violation')
plt.show()

# %%
x = (df_len_cost['violation_length'])
y = np.log(df_len_cost['Total'])
plt.scatter(x, y)
plt.plot(x, y)
plt.ylabel('log(Average Settlement Cost)')
plt.xlabel('log(Length of Violation (number of words))')
plt.title('Average Settlement Cost vs Length of Violation')
plt.show()

# %% [markdown]
# This is a PCA of the initial dataset using `n_components = 2`

# %%
min_df = 0.01
max_df = 0.90
vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))
X_dtm = vect.fit_transform(X)
pca = PCA(n_components = 2)
pca_results = pca.fit_transform(X_dtm.toarray())
print('Size of Feature Vector is: ', len(X_dtm.toarray()[0]))
# Out:
# Size of Feature Vector is:  93

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.22309807,  0.10474629])

# %%
print('Total Variance', (pca.explained_variance_ratio_[0] + pca.explained_variance_ratio_[1]) * 100, '%')
# Out:
# Total Variance 32.7844360176 %

# %%
per_var = np.round(pca.explained_variance_ratio_ * 100, decimals = 1)
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
plt.bar(x = range(1, len(per_var)+1), height=per_var, tick_label = labels)
plt.xlabel('Principal Component', fontsize = 14)
plt.ylabel('% of Explained Variance', fontsize = 14)
plt.show()

# %%
pca_df = pd.DataFrame(pca_results, columns=['x', 'y'])
pca_df['violation_text'] = df_all2['violation_data']
pca_df['facility_type'] = df_all2['facility_type']
pca_df['Total_Settlement'] = df_all2['Total']

# %%
pca_df.head()
# Out:
#           x         y                                     violation_text  \
# 0 -0.371814  2.367827  failed to reconcile quarterly nox emissions in...
# 1 -0.226319 -0.061812                  inaccurate qcers  inaccurate apep
# 2 -0.226319 -0.061812  failure to keep the roof of internal floating ...
# 3 -0.226319 -0.061812  failure to operate and maintain a continuous m...
# 4 -0.226319 -0.061812  selling architectural coatings within the scaq...
#
#   facility_type  Total_Settlement
# 0            rt           7200.00
# 1            rt           7200.00
# 2             t           3500.00
# 3             t           3500.00
# 4             n           9438.66

# %%
sns.lmplot( x="x", y="y", data=pca_df, fit_reg=False, hue='facility_type', legend=False)
plt.legend(loc='lower right')
plt.xlabel('PC-1', fontsize = 14)
plt.ylabel('PC-2', fontsize = 14)
plt.show()

# %%
pc1_df = pca_df[(pca_df['x'] < 0) & (pca_df['y'] > 0)].reset_index(drop=True)
pc1_df.head()
# Out:
#           x         y                                     violation_text  \
# 0 -0.371814  2.367827  failed to reconcile quarterly nox emissions in...
# 1 -0.490404  4.381286  failed to reconcile quarterly nox emissions in...
# 2 -0.429718  3.347712  failed to reconcile quarterly nox emissions in...
# 3 -0.433013  3.446405  failed to reconcile quarterly nox emissions in...
# 4 -0.490404  4.381286  failed to reconcile quarterly nox emissions in...
#
#   facility_type  Total_Settlement
# 0            rt            7200.0
# 1             r           25000.0
# 2             r          150000.0
# 3             r           32500.0
# 4             r           32500.0

# %% [markdown]
# This is a tSNE of the initial dataset using `learning_rate=100` and `perplexity=40`

# %%
X = df_all2['violation_data']
y = df_all2['facility_type']
min_df = 0.01
max_df = 0.90
vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))
X_dtm = vect.fit_transform(X)

# %%
start = time.time()

model = TSNE(learning_rate=100, perplexity=40)
transformed = model.fit_transform(X_dtm.toarray())

end = time.time()
print('Elapsed time: ', end - start, 'seconds')
# Out:
# Elapsed time:  96.25770211219788 seconds

# %%
tsne_df = pd.DataFrame(transformed, columns=['x', 'y'])
tsne_df['violation_text'] = df_all2['trim_violation_text']
tsne_df['facility_type'] = df_all2['facility_type']
tsne_df['Total_Settlement'] = df_all2['Total']
tsne_df.head()
# Out:
#            x          y                                     violation_text  \
# 0 -14.181170  33.906322  failed to reconcile quarterly nox emissions in...
# 1   3.863212   3.823539                   inaccurate qcers inaccurate apep
# 2   3.655426   2.095896  failure to keep the roof of internal floating ...
# 3   3.642843   2.139420  failure to operate and maintain a continuous m...
# 4   4.368749   1.879424  selling architectural coatings within the scaq...
#
#   facility_type  Total_Settlement
# 0            rt           7200.00
# 1            rt           7200.00
# 2             t           3500.00
# 3             t           3500.00
# 4             n           9438.66

# %%
plt.figure(figsize=(20,10))
sns.lmplot( x="x", y="y", data=tsne_df, fit_reg=False, hue='facility_type', legend=False)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# This is a SVD of the initial dataset using `n_components = 2`

# %%
X = df_all2['violation_data']
y = df_all2['facility_type']
min_df = 0.01
max_df = 0.90
vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))
X_dtm = vect.fit_transform(X)

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=2)
svd_ctv = svd.fit_transform(X_dtm)

# %%
svd_df = pd.DataFrame(svd_ctv, columns=['x', 'y'])
svd_df['violation_text'] = df_all2['trim_violation_text']
svd_df['facility_type'] = df_all2['facility_type']
svd_df['Total_Settlement'] = df_all2['Total']
svd_df.head()
# Out:
#               x             y  \
# 0 -2.573922e-07  2.441393e+00
# 1 -2.152054e-18  1.540688e-16
# 2 -3.906181e-18  1.743084e-16
# 3  2.551050e-19 -2.210007e-17
# 4 -5.142738e-19 -3.471811e-18
#
#                                       violation_text facility_type  \
# 0  failed to reconcile quarterly nox emissions in...            rt
# 1                   inaccurate qcers inaccurate apep            rt
# 2  failure to keep the roof of internal floating ...             t
# 3  failure to operate and maintain a continuous m...             t
# 4  selling architectural coatings within the scaq...             n
#
#    Total_Settlement
# 0           7200.00
# 1           7200.00
# 2           3500.00
# 3           3500.00
# 4           9438.66

# %%
plt.figure(figsize=(20,10))
sns.lmplot( x="x", y="y", data=svd_df, fit_reg=False, hue='facility_type', legend=False)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## k-Means on the initial dataset

# %%
X = df_all2['trim_violation_text']
y = df_all2['facility_type']
min_df = 0.01
max_df = 0.90
vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))
X_dtm = vect.fit_transform(X)
print('Size of Feature Vector is: ', len(X_dtm.toarray()[0]))
# Out:
# Size of Feature Vector is:  93

# %%
start = time.time()

metric_ = []
silhouette_avg_ = []
for i in range(2, 25):
    kmeans = KMeans(n_clusters=i, random_state=10)
    kmeans.fit(X_dtm)
    metric_.append(kmeans.inertia_)
    labels = kmeans.predict(X_dtm)
    silhouette_avg = silhouette_score(X_dtm, labels)
    silhouette_avg_.append(silhouette_avg)

end = time.time()
print('Elapsed time: ', end - start, 'seconds')
# Out:
# Elapsed time:  15.299937963485718 seconds

# %%
cluster = [x for x in range(2, 25)]
plt.scatter(cluster, metric_)
plt.plot(cluster, metric_)
plt.ylabel('k-means Inertia')
plt.xlabel('Number of Clusters')
plt.title('Elbow Chart of k-Means Clusters')
plt.show()

# %%
cluster = [x for x in range(2, 25)]
plt.scatter(cluster, silhouette_avg_)
plt.plot(cluster, silhouette_avg_)
plt.ylabel('k-means Silhouette Average')
plt.xlabel('Number of Clusters')
plt.title('Silhouette Average of k-Means Clusters')
plt.show()

# %%
silhouette_avg_
# Out:
# [0.60241029031399684,
#  0.62015168039939439,
#  0.61481893669484877,
#  0.6302003614998678,
#  0.64042400301634184,
#  0.63609438445326438,
#  0.62984720062006705,
#  0.63176938159075435,
#  0.64243169391604271,
#  0.63567493853020973,
#  0.57100310038588731,
#  0.59234221762674599,
#  0.58892604355603584,
#  0.60592643838636895,
#  0.61193787690966295,
#  0.6060888240305774,
#  0.58829540863535312,
#  0.63082563256988378,
#  0.605879799780354,
#  0.59142422079704249,
#  0.61078687756101635,
#  0.62573499345047134,
#  0.62001885422017888]

# %%
silhouette_avg_[4]
# Out:
# 0.64042400301634184

# %%
X_dtm = vect.fit_transform(X)
kmeans = KMeans(n_clusters=6, random_state=10)
kmeans.fit(X_dtm)
labels = kmeans.predict(X_dtm)
labels
# Out:
# array([2, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
kmeans_df = pd.DataFrame()
kmeans_df['violation_text'] = df_all2['trim_violation_text']
kmeans_df['facility_type'] = df_all2['facility_type']
kmeans_df['Total_Settlement'] = df_all2['Total']
kmeans_df['Cluster'] = labels
kmeans_df['notification'] = df_all2['notification']
kmeans_df['facility_id'] = df_all2['facility id']
kmeans_df.head(10)
# Out:
#                                       violation_text facility_type  \
# 0  failed to reconcile quarterly nox emissions in...            rt
# 1                   inaccurate qcers inaccurate apep            rt
# 2  failure to keep the roof of internal floating ...             t
# 3  failure to operate and maintain a continuous m...             t
# 4  selling architectural coatings within the scaq...             n
# 5  failure to conduct reverification test months ...             n
# 6  failure to post permit on site failure to prov...             n
# 7  operating a gasoline dispensing facility contr...             n
# 8  two vapor recovery hoses leaking above ppm voc...             t
# 9  operating an ajax boiler rated at million btuh...             n
#
#    Total_Settlement  Cluster notification facility_id
# 0           7200.00        2       P56324        3704
# 1           7200.00        0       P56323        3704
# 2           3500.00        0       P37231        2526
# 3           3500.00        0       P37230        2526
# 4           9438.66        0       P60306      158141
# 5           1000.00        0       P59039      115862
# 6           1000.00        0       P61478      115862
# 7           1000.00        1       P61475      115862
# 8           3000.00        0       P52622      800057
# 9           2500.00        0       P61702       84456

# %%
kmeans_df[kmeans_df['Cluster'] ==  2].to_csv('cluster2.csv', index=False)

# %%
facility_type_ = dict()
type_list = range(0, 7)
for each in type_list:
    text = ' '.join(kmeans_df.loc[kmeans_df['Cluster'] == each, 'violation_text'].values)
    facility_type_[each] = word_tokenize(text)

# %%
Counter(facility_type_[0]).most_common(20)
# Out:
# [('to', 3369),
#  ('the', 1781),
#  ('of', 1743),
#  ('failure', 1624),
#  ('a', 1611),
#  ('and', 1173),
#  ('operating', 1062),
#  ('permit', 998),
#  ('for', 927),
#  ('in', 807),
#  ('without', 773),
#  ('with', 708),
#  ('operate', 501),
#  ('test', 464),
#  ('on', 454),
#  ('compliance', 431),
#  ('an', 424),
#  ('conduct', 419),
#  ('facility', 408),
#  ('not', 373)]

# %%
Counter(facility_type_[1]).most_common(20)
# Out:
# [('and', 76),
#  ('a', 70),
#  ('operating', 48),
#  ('dispensing', 48),
#  ('gasoline', 46),
#  ('to', 46),
#  ('contrary', 44),
#  ('carb', 44),
#  ('executive', 43),
#  ('orders', 43),
#  ('facility', 41),
#  ('with', 38),
#  ('manufacturers', 37),
#  ('specifications', 34),
#  ('major', 33),
#  ('on', 26),
#  ('defect', 18),
#  ('defects', 14),
#  ('insertion', 14),
#  ('interlock', 14)]

# %%
Counter(facility_type_[2]).most_common(20)
# Out:
# [('the', 343),
#  ('of', 153),
#  ('emissions', 131),
#  ('nox', 128),
#  ('in', 86),
#  ('end', 86),
#  ('quarter', 59),
#  ('compliance', 52),
#  ('year', 52),
#  ('to', 46),
#  ('through', 46),
#  ('reconcile', 45),
#  ('from', 45),
#  ('exceeded', 45),
#  ('failed', 44),
#  ('annual', 44),
#  ('allocation', 44),
#  ('at', 43),
#  ('beginning', 42),
#  ('effect', 42)]

# %%
Counter(facility_type_[3]).most_common(20)
# Out:
# [('a', 270),
#  ('operating', 154),
#  ('gasoline', 154),
#  ('dispensing', 153),
#  ('with', 152),
#  ('facility', 150),
#  ('major', 144),
#  ('on', 114),
#  ('to', 108),
#  ('defect', 101),
#  ('and', 83),
#  ('failure', 54),
#  ('hose', 53),
#  ('pump', 52),
#  ('down', 35),
#  ('breakaway', 34),
#  ('interlock', 32),
#  ('in', 32),
#  ('upside', 30),
#  ('faulty', 29)]

# %%
Counter(facility_type_[4]).most_common(20)
# Out:
# [('to', 173),
#  ('failure', 145),
#  ('conduct', 124),
#  ('vapor', 116),
#  ('recovery', 111),
#  ('a', 91),
#  ('testing', 73),
#  ('of', 60),
#  ('reverification', 54),
#  ('with', 44),
#  ('test', 44),
#  ('facility', 38),
#  ('annually', 38),
#  ('for', 36),
#  ('tests', 34),
#  ('monthly', 33),
#  ('semiannually', 30),
#  ('as', 30),
#  ('required', 30),
#  ('gasoline', 29)]

# %%
Counter(facility_type_[5]).most_common(20)
# Out:
# [('a', 236),
#  ('to', 235),
#  ('operating', 190),
#  ('gasoline', 182),
#  ('facility', 170),
#  ('dispensing', 167),
#  ('permit', 120),
#  ('contrary', 96),
#  ('without', 62),
#  ('failure', 61),
#  ('carb', 56),
#  ('and', 55),
#  ('with', 53),
#  ('of', 51),
#  ('operate', 48),
#  ('valid', 45),
#  ('isd', 44),
#  ('in', 42),
#  ('conduct', 29),
#  ('n', 29)]

# %%
group_zero = Counter(facility_type_[0]).most_common(100)
group_one = Counter(facility_type_[1]).most_common(100)
group_two = Counter(facility_type_[2]).most_common(100)
group_three = Counter(facility_type_[3]).most_common(100)
group_four = Counter(facility_type_[4]).most_common(100)
group_five = Counter(facility_type_[5]).most_common(100)

# %%
def create_wordcloud(d):
    wordcloud = WordCloud(background_color='white',
                          max_words=50, 
                          max_font_size=40,
                          random_state=42).generate(str(d))
    return wordcloud

# %%
fig, axes = plt.subplots(3, 2, figsize=(30, 30))

ax = axes[0, 0]
ax.imshow(create_wordcloud(group_zero), interpolation="bilinear")
ax.axis('off')
ax.set_title("Cluster 0", fontsize=30)

ax = axes[0, 1]
ax.imshow(create_wordcloud(group_one))
ax.axis('off')
ax.set_title("Cluster 1", fontsize=30)

ax = axes[1, 0]
ax.imshow(create_wordcloud(group_two))
ax.axis('off')
ax.set_title("Cluster 2", fontsize=30)

ax = axes[1, 1]
ax.imshow(create_wordcloud(group_three))
ax.axis('off')
ax.set_title("Cluster 3", fontsize=30)

ax = axes[2, 0]
ax.imshow(create_wordcloud(group_four))
ax.axis('off')
ax.set_title("Cluster 4", fontsize=30)

ax = axes[2, 1]
ax.imshow(create_wordcloud(group_five))
ax.axis('off')
ax.set_title("Cluster 5", fontsize=30)
plt.show()

plt.show()

# %%
df_cross_tab = kmeans_df.iloc[:, 1:4]
cross_tab_summary = pd.crosstab(df_cross_tab['facility_type'], df_cross_tab['Cluster'])
cross_tab_summary
# Out:
# Cluster           0   1   2    3   4    5
# facility_type
# n              2114  41   1  144  96  156
# r               115   1  26    0   0    0
# rt              262   1  19    0   0    0
# t               228   0   0    0   0    0

# %%
start = time.time()

model = TSNE(learning_rate=100, perplexity=50)
transformed = model.fit_transform(X_dtm.toarray())

end = time.time()
print('Elapsed time: ', end - start, 'seconds')
# Out:
# Elapsed time:  111.60546398162842 seconds

# %%
tsne_df = pd.DataFrame(transformed, columns=['x', 'y'])
tsne_df['violation_text'] = kmeans_df['violation_text']
tsne_df['facility_type'] = kmeans_df['facility_type']
tsne_df['Total_Settlement'] = kmeans_df['Total_Settlement'] 
tsne_df['Cluster'] = labels

# %%
tsne_df.head()
# Out:
#            x          y                                     violation_text  \
# 0  25.908875 -18.974020  failed to reconcile quarterly nox emissions in...
# 1   4.776896   2.578715                   inaccurate qcers inaccurate apep
# 2   4.453410   2.831712  failure to keep the roof of internal floating ...
# 3   6.167253   3.350573  failure to operate and maintain a continuous m...
# 4   4.429774   2.837464  selling architectural coatings within the scaq...
#
#   facility_type  Total_Settlement  Cluster
# 0            rt           7200.00        2
# 1            rt           7200.00        0
# 2             t           3500.00        0
# 3             t           3500.00        0
# 4             n           9438.66        0

# %%
tsne_df.shape
# Out:
# (3204, 6)

# %%
tsne_df['violation_text'].isnull().sum()
# Out:
# 0

# %%
tsne_df = tsne_df.dropna(axis=0, how='any')

# %%
tsne_df.shape
# Out:
# (3204, 6)

# %%
tsne_df[tsne_df['Cluster'] == 0].head(20)
# Out:
#             x          y                                     violation_text  \
# 1    4.776896   2.578715                   inaccurate qcers inaccurate apep
# 2    4.453410   2.831712  failure to keep the roof of internal floating ...
# 3    6.167253   3.350573  failure to operate and maintain a continuous m...
# 4    4.429774   2.837464  selling architectural coatings within the scaq...
# 5    5.099338 -49.149570  failure to conduct reverification test months ...
# 6  -26.001879  28.084589  failure to post permit on site failure to prov...
# 8    4.007535   3.294319  two vapor recovery hoses leaking above ppm voc...
# 9   30.610558  32.092934  operating an ajax boiler rated at million btuh...
# 10   5.061747   2.219471  emitting more than permitted limit for nox and...
# 11   1.466156 -33.185211  operating gasoline dispensing equipment after ...
# 12 -14.943787 -20.183687  permit condition gasoline dispensing facility ...
# 13   5.961406   1.956079  failure to submit an annual permit emissions p...
# 14   5.677537   1.450185                     open ended line uncapped valve
# 15   5.680638   1.453590  failed to submit daily emissions reports in a ...
# 17 -29.623474  34.779541  failure to show compliance by operating above ...
# 18   6.078708   2.728555  selling architectural coatings within the scaq...
# 19   4.307436   2.969985  the electronic report of daily mass emissions ...
# 20 -35.474838  -5.671918  operating a diesel fueled engine during school...
# 21   4.061691   3.167280  visible emissions in excess of opacityfor over...
# 22   5.094446   2.104423  exceede provided character space please view t...
#
#    facility_type  Total_Settlement  Cluster
# 1             rt           7200.00        0
# 2              t           3500.00        0
# 3              t           3500.00        0
# 4              n           9438.66        0
# 5              n           1000.00        0
# 6              n           1000.00        0
# 8              t           3000.00        0
# 9              n           2500.00        0
# 10             n           1200.00        0
# 11             n           1000.00        0
# 12             n           1000.00        0
# 13             r           1200.00        0
# 14             n          10000.00        0
# 15             r          10625.00        0
# 17             n           1600.00        0
# 18             n            500.00        0
# 19            rt           1000.00        0
# 20             n           1650.00        0
# 21             n           1600.00        0
# 22             n           5500.00        0

# %%
tsne_df[tsne_df['Cluster'] == 1].head(20)
# Out:
#               x          y                                     violation_text  \
# 7    -14.065142 -53.942070  operating a gasoline dispensing facility contr...
# 40   -15.569848 -51.606949  operating a gasoline dispensing facility contr...
# 41   -15.569848 -51.606949  operating a gasoline dispensing facility contr...
# 42   -15.569848 -51.606949  operating a gasoline dispensing facility contr...
# 114  -15.244950 -54.616398  operating a gasoline dispensing facility contr...
# 115  -15.244950 -54.616398  operating a gasoline dispensing facility contr...
# 116  -14.940183 -54.062325  operating a gasoline dispensing facility contr...
# 459  -15.569895 -51.607258  operating a gasoline dispensing facility contr...
# 473  -14.341129 -53.775249  operating a gasoline dispensing facility contr...
# 478  -15.108324 -52.836826  operating a gasoline dispensing facility contr...
# 498  -14.402115 -54.830868  operating a gasoline dispensing facility contr...
# 533  -14.402115 -54.830868  operating a gasoline dispensing facility contr...
# 592  -14.402115 -54.830868  operating a gasoline dispensing facility contr...
# 774  -14.547679 -56.074394  operating a gasoloine dispensing facility cont...
# 854  -36.675270 -35.487473  operating a gasoline dispensing facility with ...
# 887  -16.450367 -55.068462  operating a gasoline dispensing facility contr...
# 954  -14.402115 -54.830868  operating a gasoline dispensing facility contr...
# 1260 -14.402115 -54.830868  operating a gasoline dispensing facility contr...
# 1500 -14.341129 -53.775249  operating a gasoline dispensing facility contr...
# 1552 -14.933208 -55.574417  operating a gaosline dispensing facility contr...
#
#      facility_type  Total_Settlement  Cluster
# 7                n            1000.0        1
# 40               n             650.0        1
# 41               n             650.0        1
# 42               n             650.0        1
# 114              n             200.0        1
# 115             rt             500.0        1
# 116              r             500.0        1
# 459              n             550.0        1
# 473              n            5000.0        1
# 478              n            1925.0        1
# 498              n             330.0        1
# 533              n             975.0        1
# 592              n             425.0        1
# 774              n           10000.0        1
# 854              n             500.0        1
# 887              n            5000.0        1
# 954              n             825.0        1
# 1260             n            1470.0        1
# 1500             n             400.0        1
# 1552             n             890.0        1

# %%
tsne_df[tsne_df['Cluster'] == 2].head(20)
# Out:
#               x          y                                     violation_text  \
# 0     25.908875 -18.974020  failed to reconcile quarterly nox emissions in...
# 82    26.126410 -21.488939  failed to reconcile quarterly nox emissions in...
# 112   25.953077 -23.875496  failed to reconcile quarterly nox emissions in...
# 259   27.058805 -19.153570  failed to reconcile quarterly nox emissions in...
# 261   26.126410 -21.488939  failed to reconcile quarterly nox emissions in...
# 264   23.300940 -23.273821  failed to reconcile qrtrly nox emissions in th...
# 389   26.126410 -21.488939  failed to reconcile quarterly nox emissions in...
# 438   23.691154 -21.520908  failed to reconcile nox emissions in the first...
# 541   25.909431 -19.168571   failed to reconcile quarterly nox emissions i...
# 648   26.339611 -22.148193   failed to reconcile quarterly nox emissions i...
# 652   25.953077 -23.875496  failed to reconcile quarterly nox emissions in...
# 883   23.546944 -18.698132  for compliance year nox emissions from the beg...
# 963   26.339611 -22.148193  failed to reconcile quarterly nox emissions in...
# 1035  23.445724 -23.513281   nox emissions from the beginning of the cy th...
# 1036  26.339611 -22.148193   failed to reconcile quarterly nox emissions i...
# 1078  24.294857 -22.031437  failed to reconcile nox emissions in the fourt...
# 1094  26.339611 -22.148193  failed to reconcile quarterly nox emissions in...
# 1126  27.058805 -19.153570  failed to reconcile quarterly nox emissions in...
# 1151  26.339611 -22.148193  failed to reconcile quarterly nox emissions in...
# 1295  26.339611 -22.148193   failed to reconcile quarterly nox emissions i...
#
#      facility_type  Total_Settlement  Cluster
# 0               rt            7200.0        2
# 82               r           25000.0        2
# 112              r          150000.0        2
# 259              r           32500.0        2
# 261              r           32500.0        2
# 264             rt            7500.0        2
# 389             rt            1000.0        2
# 438              r            3000.0        2
# 541             rt           31000.0        2
# 648             rt            4500.0        2
# 652             rt           29900.0        2
# 883              r           10000.0        2
# 963             rt            3000.0        2
# 1035             r            6000.0        2
# 1036             r            6000.0        2
# 1078            rt            1000.0        2
# 1094             r            6500.0        2
# 1126             r           50000.0        2
# 1151            rt           42500.0        2
# 1295             r            1700.0        2

# %%
tsne_df[tsne_df['Cluster'] == 3].head(20)
# Out:
#              x          y                                     violation_text  \
# 46  -40.475613 -27.719450  operating a gasoline dispensing facility with ...
# 59  -42.045555 -28.248091  operating gasoline dispensing facility with a ...
# 77  -41.172131 -29.445272  operating a gasoline dispensing facility with ...
# 123 -42.339615 -30.519089  operating a gasoline dispensing facility with ...
# 124 -31.979153 -37.748810  operating a gasoline dispensing facility with ...
# 131 -39.311577 -31.356768  operating a gasoline dispensing facility with ...
# 136 -39.729385 -25.110035  failure to comply with notice to comply e item...
# 142 -33.874989 -37.512463  operating a gasoline dispensing facility with ...
# 219 -42.955444 -27.592627  operating a gasoline dispensing facility with ...
# 236 -43.461349 -28.222807  operating a gasoline dispensing facility with ...
# 239 -43.461349 -28.222807  operating a gasoline dispensing facility with ...
# 241 -40.744358 -28.537678  operating a gasoline dispensing facility with ...
# 242 -33.880428 -37.508976  operating a gasoline dispensing facility with ...
# 244 -45.995876 -32.348286  operating a gasoline dispensing facility with ...
# 249 -31.561108 -37.133614  operating a gasoline dispensing facility with ...
# 255 -42.443684 -29.607214  operating a gasoline dispensing facility with ...
# 271 -44.101734 -25.920609  operating a gasoline dispensing facility with ...
# 273 -43.461349 -28.222807  operating a gasoline dispensing facility with ...
# 274 -42.803146 -29.508083  operating a gasoline dispensing facility with ...
# 275 -42.577789 -27.265989  operating a gasoline dispensing facility with ...
#
#     facility_type  Total_Settlement  Cluster
# 46              n             560.0        3
# 59              n             750.0        3
# 77              n             550.0        3
# 123             n             300.0        3
# 124             n            1450.0        3
# 131             n             550.0        3
# 136             n            3750.0        3
# 142             n            1100.0        3
# 219             n             300.0        3
# 236             n             600.0        3
# 239             n             650.0        3
# 241             n             600.0        3
# 242             n            1500.0        3
# 244             n             550.0        3
# 249             n             715.0        3
# 255             n             900.0        3
# 271             n            2500.0        3
# 273             n            2500.0        3
# 274             n            2500.0        3
# 275             n            2500.0        3

# %%
tsne_df[tsne_df['Cluster'] == 4].head(20)
# Out:
#              x         y                                     violation_text  \
# 49  -55.094376  0.013848  failure to conduct vapor recovery testing semi...
# 69  -46.144741  4.497012  failure to conduct vapor recovery reverificati...
# 135 -48.314426  2.325479  failure to conduct vapor recovery reverificati...
# 156 -46.469627  3.868580  failure to conduct vapor recovery reverificati...
# 163 -48.998375  1.952678  failure to conduct vapor recovery reverificati...
# 206 -45.582321  3.600862  failure to conduct vapor recovery reverificati...
# 224 -45.578289  3.605796  failure to conduct vapor recovery reverificati...
# 229 -46.547482  4.744931  failure to conduct vapor recovery reverificati...
# 234 -45.803997  5.435524  operating a gasoline storage and dispensing sy...
# 279 -46.144741  4.497012  failure to conduct vapor recovery reverificati...
# 300 -51.995907  1.223043  failure to conduct vapor recovery system s rev...
# 358 -56.157879  0.100576  failure to providrecords demonstrating complia...
# 462 -46.469627  3.868580  failure to conduct vapor recovery reverificati...
# 489 -55.702503 -1.430935  failure to provide records demonstrating compl...
# 497 -51.995907  1.223044  failure to conduct vapor recovery reverificiat...
# 504 -55.099674 -0.408063  failure to conduct vapor recovery testing in a...
# 505 -55.099674 -0.408063  failure to conduct vapor recovery testing in a...
# 513 -51.995907  1.223044  failure to conduct vapor recovery performance ...
# 518 -55.094376  0.013848  failure to porivde records demonstrating compl...
# 526 -55.702503 -1.430935  failure to provide records demonstrating compl...
#
#     facility_type  Total_Settlement  Cluster
# 49              n            1500.0        4
# 69              n             375.0        4
# 135             n             600.0        4
# 156             n             600.0        4
# 163             n             700.0        4
# 206             n             600.0        4
# 224             n             200.0        4
# 229             n             850.0        4
# 234             n            1450.0        4
# 279             n             550.0        4
# 300             n             850.0        4
# 358             n            1320.0        4
# 462             n             145.0        4
# 489             n             990.0        4
# 497             n             450.0        4
# 504             n             200.0        4
# 505             n             200.0        4
# 513             n             390.0        4
# 518             n             630.0        4
# 526             n            2100.0        4

# %%
tsne_df[tsne_df['Cluster'] == 5].head(20)
# Out:
#              x          y                                     violation_text  \
# 16  -22.799841 -38.715328  operating a gasoline dispensing facility not a...
# 37  -22.799841 -38.715328  operating a gasoline dispensing facility with ...
# 104 -19.944033 -43.830868   operating a gasoline dispensing facility cont...
# 105 -18.720959 -43.228569   operating a gasoline dispensing facility cont...
# 127 -17.040684 -40.613499  operating a gasoline dispensing facility contr...
# 128 -23.007463 -38.531876  operating a gasoline dispensing facility with ...
# 157 -17.767775 -47.242603  failure to replace hose within days of issuanc...
# 217 -18.721184 -43.228523  failure to repairreplace vapor recovery compon...
# 231 -23.658195 -29.687229  operating a gasoline dispensing facility witho...
# 243 -21.071234 -43.308670   operating a gasoline dispensing facility cont...
# 252 -21.455681 -43.864990  failure to conduct periodic compliance inspect...
# 253   2.296890 -49.693195  failure to conduct periodic compliance inspect...
# 280 -17.334549 -47.629734  operating a gasoline dispensing facility contr...
# 304 -17.041523 -40.609882  operating a gasoline dispensing facility contr...
# 313 -22.975863 -29.279633  operating a gasoline dispensing facility witho...
# 368 -25.344952 -32.568832  operating a gasoline dispensing facility witho...
# 371 -22.975863 -29.279633  operating a gasoline dispensing facility witho...
# 420 -21.748278 -38.490200  operating a gasoline dispensing facility with ...
# 427   2.294682 -49.640083  failure to conduct reverification test months ...
# 428 -21.778532 -38.539593  operating a gasoline dispensing facility with ...
#
#     facility_type  Total_Settlement  Cluster
# 16              n            1600.0        5
# 37              n             650.0        5
# 104             n            6500.0        5
# 105             n            6500.0        5
# 127             n             750.0        5
# 128             n             450.0        5
# 157             n            1650.0        5
# 217             n            1000.0        5
# 231             n             400.0        5
# 243             n            1200.0        5
# 252             n            1800.0        5
# 253             n            1100.0        5
# 280             n             400.0        5
# 304             n            1200.0        5
# 313             n             420.0        5
# 368             n             900.0        5
# 371             n             550.0        5
# 420             n             650.0        5
# 427             n            1550.0        5
# 428             n            1800.0        5

# %%
plt.figure(figsize=(20,10))
sns.lmplot( x="x", y="y", data=tsne_df, fit_reg=False, hue='Cluster', legend=False)
plt.legend(loc='lower right')
plt.show()

# %%
def tsne_run(lr, perp):
    start = time.time()

    X = df_all2['violation_data']
    y = df_all2['facility_type']

    min_df = 0.01
    max_df = 0.90

    vect = CountVectorizer(stop_words='english', min_df=min_df, max_df=max_df, ngram_range=(3,4))
    X_dtm = vect.fit_transform(X)

    kmeans = KMeans(n_clusters=6, random_state=10)
    kmeans.fit(X_dtm)
    labels = kmeans.predict(X_dtm)
    
    kmeans_df = pd.DataFrame()
    kmeans_df['violation_text'] = df_all2['trim_violation_text']
    kmeans_df['facility_type'] = df_all2['facility_type']
    kmeans_df['Total_Settlement'] = df_all2['Total']
    kmeans_df['Cluster'] = labels

    model = TSNE(learning_rate=lr, perplexity=perp)
    transformed = model.fit_transform(X_dtm.toarray())

    tsne_df = pd.DataFrame(transformed, columns=['x', 'y'])
    tsne_df['violation_text'] = kmeans_df['violation_text']
    tsne_df['facility_type'] = kmeans_df['facility_type']
    tsne_df['Total_Settlement'] = kmeans_df['Total_Settlement'] 
    tsne_df['Cluster'] = labels

    plt.figure(figsize=(20,10))
    sns.lmplot( x="x", y="y", data=tsne_df, fit_reg=False, hue='Cluster', legend=False)
    plt.legend(loc='lower right')
    plt.show()

    end = time.time()
    print('Elapsed time: ', end - start, 'seconds')

# %%
tsne_run(90, 50)
# Out:
# Elapsed time:  110.25576901435852 seconds

# %%
tsne_run(100, 50)
# Out:
# Elapsed time:  112.15708112716675 seconds

# %%
tsne_run(150, 50)
# Out:
# Elapsed time:  121.40987491607666 seconds

# %%
tsne_run(200, 50)
# Out:
# Elapsed time:  117.56658792495728 seconds

# %%
tsne_run(250, 50)
# Out:
# Elapsed time:  124.63041186332703 seconds

# %%
#https://stackoverflow.com/questions/24647400/what-is-the-best-stemming-method-in-python
#https://pythonprogramming.net/stemming-nltk-tutorial/

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
lmtzr = WordNetLemmatizer()
ps = PorterStemmer()

# %%
a = 'failure to operate and maintain a continuous monitoring system cms according to rule plan'
a_list = a.split(' ')
list_= [lmtzr.lemmatize(each) for each in a_list]
b = ' '.join(list_)
a_list = b.split(' ')
list_= [ps.stem(each) for each in a_list]
a = ' '.join(list_)

# %%
a
# Out:
# 'failur to oper and maintain a continu monitor system cm accord to rule plan'

# %%
b
# Out:
# 'failure to operate and maintain a continuous monitoring system cm according to rule plan'
